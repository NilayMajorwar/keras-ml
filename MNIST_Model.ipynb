# %%
import numpy as np
from keras.datasets import mnist
from keras.layers import Flatten
from keras.layers import Dense
from keras import *
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train / 255.0

# %%
model = Sequential()
model.add(Flatten())
model.add(Dense(100, activation = tf.nn.relu))
model.add(Dense(10, activation = tf.nn.softmax))
model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])
model.fit(x_train, y_train, epochs = 5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.2719 - acc: 0.9230
# Epoch 2/5
# 60000/60000 [==============================] - 5s 88us/step - loss: 0.1270 - acc: 0.9628
# Epoch 3/5
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.0901 - acc: 0.9732
# Epoch 4/5
# 60000/60000 [==============================] - 5s 88us/step - loss: 0.0682 - acc: 0.9793
# Epoch 5/5
# 60000/60000 [==============================] - 5s 87us/step - loss: 0.0537 - acc: 0.9833

# %%
model.evaluate(x_test, y_test)
# Out:
# 10000/10000 [==============================] - 0s 26us/step
# [0.4361740371939617, 0.9727]

# %%
model.predict(x_train[52].reshape(1, 28, 28))
# Out:
# array([[2.0402585e-10, 2.0646488e-16, 2.5816624e-07, 6.6243032e-08,
#         2.5979552e-13, 4.5645918e-09, 1.6167632e-17, 9.9999642e-01,
#         7.6785456e-10, 3.2226105e-06]], dtype=float32)

# %%
plt.imshow(x_train[52])
